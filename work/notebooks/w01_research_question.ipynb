# %% [markdown]
# <a href="https://colab.research.google.com/github/DanialHameed/fly/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/DanialHameed/fly/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ### 1. My lane (or freestyle) and why
#
# I'm going with **Lane 2: Refresh / Content Opportunity Scoring** — one of the
# four predefined lanes. This lane asks which pages should be reviewed first for
# refresh, expansion, protection, pruning, or monitoring, based on evidence from
# search performance signals.
#
# I picked this over freestyling because the starter pipeline already implements
# a full working example of it end to end — a transparent baseline score, a
# trained model, and a validated comparison between the two. That lets me spend
# my first notebook understanding *why* the learned model beats the hand-written
# rule, instead of spending it inventing a labeling scheme from scratch. It's
# also close to problems I'd want to work on later: turning messy signals into a
# concrete, prioritized action for a real person to take.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The decision this improves: which pages from the backlog get picked up for content review this cycle, out of many more candidates than the team has time to touch.
# Who acts on it: whoever owns the content/SEO review queue — they take the ranked list and work through it top-down instead of guessing or going alphabetically.
# Cost of a wrong call: two ways to be wrong, and they cost differently.
#
# False positive (recommending a page that didn't need work): wastes review time on a page that wouldn't have moved, while a page that actually needed help sits untouched.
# False negative (missing a page that did need work): the page keeps losing traffic silently until someone notices, by which point recovery is harder and slower.

# %% [markdown]
# ### 2. The question: decision, action, cost of a wrong call
#
# The decision this improves: which pages from the backlog get picked up for
# content review this cycle, out of many more candidates than the team has time
# to touch.
#
# Who acts on it: whoever owns the content/SEO review queue — they take the
# ranked list and work through it top-down instead of guessing.
#
# Cost of a wrong call:
# - False positive (recommending a page that didn't need work): wastes review
#   time on a page that wouldn't have moved.
# - False negative (missing a page that did need work): the page keeps losing
#   traffic silently until someone notices, by which point recovery is harder.
#
# Since review time is the scarce resource, precision at the top of the list
# (Precision@50, matching the pipeline's own metric) matters more than covering
# every possible page.
#
# Why data/ML helps here, not just a rule: no single signal decides whether a
# page is worth reviewing — visibility, freshness, position, and demand all
# interact. The starter pipeline's own baseline rule proves this: it reaches
# only ~24% precision on its top 50 picks (`outputs/model_report.md`), while a
# model that learns the interaction between signals reaches ~74%. That gap is
# the evidence that this problem needs learned weighting across signals, not a
# hand-tuned threshold rule.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os

# clone the repo if we're not already inside it
if not os.path.exists("data/raw/content_refresh_anonymized.csv"):
    if not os.path.exists("/content/fly"):
        # !git clone https://github.com/DanialHameed/fly.git /content/fly
    os.chdir("/content/fly")

print("Working directory:", os.getcwd())
print("Data file exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))

import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print(f"Rows: {len(df):,}")
print(f"Unique clients: {df['client_id'].nunique()}")
print()

print("trend_direction breakdown (%):")
print(df['trend_direction'].value_counts(normalize=True).mul(100).round(1))
print()

down_pages = df[df['trend_direction'] == 'down']
print(f"Median trend_pct for declining pages: {down_pages['trend_pct'].median():.1f}%")
print(f"Declining pages count: {len(down_pages):,}")
# Out:
# Working directory: /content/fly
# Data file exists: True
# Rows: 30,000
# Unique clients: 32
#
# trend_direction breakdown (%):
# trend_direction
# down      54.2
# stable    19.9
# up        14.6
# new        7.5
# flat       3.8
# Name: proportion, dtype: float64
#
# Median trend_pct for declining pages: -55.6%
# Declining pages count: 16,262

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What this work will be able to say:
# - Observed: which pages, in this anonymized sample, are trending down and by
#   how much.
# - Directional: which signals (position, CTR, freshness) tend to move together
#   with declining pages — not proof that one causes the other.
# - Decision-support: a ranked shortlist that helps a reviewer prioritize their
#   time, not a replacement for their judgment on any single page.
#
# What it will never say:
# - Causal proof — that changing X on a page will cause its ranking to improve.
#   Correlation in this data isn't evidence of what Google's algorithm actually
#   weighs.
# - "Predicting Google" — this model predicts patterns in *this client's*
#   historical search data, not the search engine's future behavior or updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
